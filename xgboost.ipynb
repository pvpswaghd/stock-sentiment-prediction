# %%
import xgboost as xgb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
from sklearn.metrics import mean_squared_error

plt.style.use('fivethirtyeight')

df = yf.download("TSLA", start="2019-01-01", end="2020-12-31")

df.index = pd.to_datetime(df.index)
df.index
# Out:
# [*********************100%***********************]  1 of 1 completed
# DatetimeIndex(['2019-01-02', '2019-01-03', '2019-01-04', '2019-01-07',
#                '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11',
#                '2019-01-14', '2019-01-15',
#                ...
#                '2020-12-16', '2020-12-17', '2020-12-18', '2020-12-21',
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-28',
#                '2020-12-29', '2020-12-30'],
#               dtype='datetime64[ns]', name='Date', length=504, freq=None)

# %%
# train_df = df.loc[df.index < '2020-09-01']
# test_df = df.loc[df.index >= '2020-09-01']

# fig, ax = plt.subplots(figsize=(15, 5))
# train_df['Close'].plot(ax=ax, label='Training')
# test_df['Close'].plot(ax=ax, label='Test')
# ax.axvline(x='2020-09-01', c='black', linestyle='--')
# ax.legend(['Training Set', 'Testing Set'])
# plt.show()

# %%
from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits=5, test_size=30, gap=1)
df = df.sort_index()

# %%
def create_features(df):
    df = df.copy()
    df['year'] = df.index.year
    df['month'] = df.index.month
    df['day'] = df.index.day
    df['dayofweek'] = df.index.dayofweek
    return df

features = ['year', 'month', 'day', 'dayofweek', 'Open', 'High', 'Low', 'Volume']
target = 'Close'

# %%
# fig, axs = plt.subplots(5, 1, figsize=(15, 15), sharex=True)

fold = 0
preds = []
scores = []
for train_idx, val_idx in tss.split(df):
    train = create_features(df.iloc[train_idx])
    test = create_features(df.iloc[val_idx])

    X_train = train[features]
    y_train = train[target]

    X_test = test[features]
    y_test = test[target]

    reg = xgb.XGBRegressor(
        base_score=0.5,
        booster='gbtree',
        n_estimators=2000,
        objective='reg:tweedie', 
        learning_rate=0.01,
        early_stopping_rounds=100,
        max_depth=3,
        )
    reg.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], verbose=100)
    y_pred = reg.predict(X_test)
    preds.append(y_pred)
    score = np.sqrt(mean_squared_error(y_test, y_pred))
    scores.append(score)

    # train['Close'].plot(ax=axs[f old], label='Training Set', title=f'Data Train / Test Split Fold {fold}')
    # test['Close'].plot(ax=axs[fold], label='Test Set')
    # axs[fold].axvline(test.index.min(), color='black', ls='--')
    # fold += 1
# Out:
# [0]	validation_0-tweedie-nloglik@1.5:73.25605	validation_1-tweedie-nloglik@1.5:197.04252
# [100]	validation_0-tweedie-nloglik@1.5:32.77532	validation_1-tweedie-nloglik@1.5:80.46598
# [200]	validation_0-tweedie-nloglik@1.5:21.99253	validation_1-tweedie-nloglik@1.5:44.32280
# [300]	validation_0-tweedie-nloglik@1.5:20.02668	validation_1-tweedie-nloglik@1.5:35.91794
# [400]	validation_0-tweedie-nloglik@1.5:19.74082	validation_1-tweedie-nloglik@1.5:34.08120
# [500]	validation_0-tweedie-nloglik@1.5:19.70149	validation_1-tweedie-nloglik@1.5:33.68142
# [600]	validation_0-tweedie-nloglik@1.5:19.69609	validation_1-tweedie-nloglik@1.5:33.57441
# [700]	validation_0-tweedie-nloglik@1.5:19.69532	validation_1-tweedie-nloglik@1.5:33.53750
# [800]	validation_0-tweedie-nloglik@1.5:19.69519	validation_1-tweedie-nloglik@1.5:33.52274
# [900]	validation_0-tweedie-nloglik@1.5:19.69515	validation_1-tweedie-nloglik@1.5:33.51783
# [1000]	validation_0-tweedie-nloglik@1.5:19.69514	validation_1-tweedie-nloglik@1.5:33.51421
# [1100]	validation_0-tweedie-nloglik@1.5:19.69513	validation_1-tweedie-nloglik@1.5:33.51264
# [1200]	validation_0-tweedie-nloglik@1.5:19.69512	validation_1-tweedie-nloglik@1.5:33.51152
# [1300]	validation_0-tweedie-nloglik@1.5:19.69511	validation_1-tweedie-nloglik@1.5:33.51066
# [1400]	validation_0-tweedie-nloglik@1.5:19.69510	validation_1-tweedie-nloglik@1.5:33.51011
# [1500]	validation_0-tweedie-nloglik@1.5:19.69509	validation_1-tweedie-nloglik@1.5:33.50970
# [1600]	validation_0-tweedie-nloglik@1.5:19.69509	validation_1-tweedie-nloglik@1.5:33.50920
# [1700]	validation_0-tweedie-nloglik@1.5:19.69508	validation_1-tweedie-nloglik@1.5:33.50888
# [1800]	validation_0-tweedie-nloglik@1.5:19.69508	validation_1-tweedie-nloglik@1.5:33.50862
# [1900]	validation_0-tweedie-nloglik@1.5:19.69507	validation_1-tweedie-nloglik@1.5:33.50830
# [1999]	validation_0-tweedie-nloglik@1.5:19.69507	validation_1-tweedie-nloglik@1.5:33.50789
# [0]	validation_0-tweedie-nloglik@1.5:82.59059	validation_1-tweedie-nloglik@1.5:296.45440
# [100]	validation_0-tweedie-nloglik@1.5:36.25344	validation_1-tweedie-nloglik@1.5:118.58588
# [200]	validation_0-tweedie-nloglik@1.5:23.54825	validation_1-tweedie-nloglik@1.5:60.80159
# [300]	validation_0-tweedie-nloglik@1.5:21.14480	validation_1-tweedie-nloglik@1.5:45.15104
# [400]	validation_0-tweedie-nloglik@1.5:20.78944	validation_1-tweedie-nloglik@1.5:41.99375
# [500]	validation_0-tweedie-nloglik@1.5:20.74038	validation_1-tweedie-nloglik@1.5:41.36621
# [600]	validation_0-tweedie-nloglik@1.5:20.73364	validation_1-tweedie-nloglik@1.5:41.21181
# [700]	validation_0-tweedie-nloglik@1.5:20.73269	validation_1-tweedie-nloglik@1.5:41.16758
# [800]	validation_0-tweedie-nloglik@1.5:20.73253	validation_1-tweedie-nloglik@1.5:41.15088
# [900]	validation_0-tweedie-nloglik@1.5:20.73249	validation_1-tweedie-nloglik@1.5:41.14524
# [1000]	validation_0-tweedie-nloglik@1.5:20.73247	validation_1-tweedie-nloglik@1.5:41.14177
# [1100]	validation_0-tweedie-nloglik@1.5:20.73246	validation_1-tweedie-nloglik@1.5:41.14045
# [1200]	validation_0-tweedie-nloglik@1.5:20.73244	validation_1-tweedie-nloglik@1.5:41.13921
# [1300]	validation_0-tweedie-nloglik@1.5:20.73243	validation_1-tweedie-nloglik@1.5:41.13862
# [1400]	validation_0-tweedie-nloglik@1.5:20.73242	validation_1-tweedie-nloglik@1.5:41.13843
# [1500]	validation_0-tweedie-nloglik@1.5:20.73241	validation_1-tweedie-nloglik@1.5:41.13833
# [1600]	validation_0-tweedie-nloglik@1.5:20.73241	validation_1-tweedie-nloglik@1.5:41.13819
# [1700]	validation_0-tweedie-nloglik@1.5:20.73240	validation_1-tweedie-nloglik@1.5:41.13809
# [1800]	validation_0-tweedie-nloglik@1.5:20.73239	validation_1-tweedie-nloglik@1.5:41.13789
# [1896]	validation_0-tweedie-nloglik@1.5:20.73239	validation_1-tweedie-nloglik@1.5:41.13790
# [0]	validation_0-tweedie-nloglik@1.5:97.89471	validation_1-tweedie-nloglik@1.5:393.51028
# [100]	validation_0-tweedie-nloglik@1.5:41.93110	validation_1-tweedie-nloglik@1.5:153.74299
# [200]	validation_0-tweedie-nloglik@1.5:25.95530	validation_1-tweedie-nloglik@1.5:73.70742
# [300]	validation_0-tweedie-nloglik@1.5:22.75413	validation_1-tweedie-nloglik@1.5:52.70253
# [400]	validation_0-tweedie-nloglik@1.5:22.26796	validation_1-tweedie-nloglik@1.5:48.43972
# [500]	validation_0-tweedie-nloglik@1.5:22.20044	validation_1-tweedie-nloglik@1.5:47.60842
# [600]	validation_0-tweedie-nloglik@1.5:22.19115	validation_1-tweedie-nloglik@1.5:47.42510
# [700]	validation_0-tweedie-nloglik@1.5:22.18983	validation_1-tweedie-nloglik@1.5:47.37527
# [800]	validation_0-tweedie-nloglik@1.5:22.18961	validation_1-tweedie-nloglik@1.5:47.36414
# [900]	validation_0-tweedie-nloglik@1.5:22.18956	validation_1-tweedie-nloglik@1.5:47.35908
# [1000]	validation_0-tweedie-nloglik@1.5:22.18954	validation_1-tweedie-nloglik@1.5:47.35706
# [1100]	validation_0-tweedie-nloglik@1.5:22.18952	validation_1-tweedie-nloglik@1.5:47.35610
# [1200]	validation_0-tweedie-nloglik@1.5:22.18951	validation_1-tweedie-nloglik@1.5:47.35558
# [1300]	validation_0-tweedie-nloglik@1.5:22.18950	validation_1-tweedie-nloglik@1.5:47.35502
# [1400]	validation_0-tweedie-nloglik@1.5:22.18948	validation_1-tweedie-nloglik@1.5:47.35461
# [1500]	validation_0-tweedie-nloglik@1.5:22.18947	validation_1-tweedie-nloglik@1.5:47.35438
# [1600]	validation_0-tweedie-nloglik@1.5:22.18946	validation_1-tweedie-nloglik@1.5:47.35439
# [1627]	validation_0-tweedie-nloglik@1.5:22.18946	validation_1-tweedie-nloglik@1.5:47.35441
# [0]	validation_0-tweedie-nloglik@1.5:117.87818	validation_1-tweedie-nloglik@1.5:396.63932
# [100]	validation_0-tweedie-nloglik@1.5:49.32460	validation_1-tweedie-nloglik@1.5:153.42090
# [200]	validation_0-tweedie-nloglik@1.5:28.99793	validation_1-tweedie-nloglik@1.5:72.07155
# [300]	validation_0-tweedie-nloglik@1.5:24.67471	validation_1-tweedie-nloglik@1.5:51.52423
# [400]	validation_0-tweedie-nloglik@1.5:23.99724	validation_1-tweedie-nloglik@1.5:48.05752
# [500]	validation_0-tweedie-nloglik@1.5:23.90253	validation_1-tweedie-nloglik@1.5:47.58220
# [600]	validation_0-tweedie-nloglik@1.5:23.88951	validation_1-tweedie-nloglik@1.5:47.51948
# [700]	validation_0-tweedie-nloglik@1.5:23.88768	validation_1-tweedie-nloglik@1.5:47.51236
# [800]	validation_0-tweedie-nloglik@1.5:23.88739	validation_1-tweedie-nloglik@1.5:47.51183
# [876]	validation_0-tweedie-nloglik@1.5:23.88732	validation_1-tweedie-nloglik@1.5:47.51193
# [0]	validation_0-tweedie-nloglik@1.5:135.59170	validation_1-tweedie-nloglik@1.5:563.73170
# [100]	validation_0-tweedie-nloglik@1.5:55.87652	validation_1-tweedie-nloglik@1.5:216.14861
# [200]	validation_0-tweedie-nloglik@1.5:31.68912	validation_1-tweedie-nloglik@1.5:98.26447
# [300]	validation_0-tweedie-nloglik@1.5:26.37036	validation_1-tweedie-nloglik@1.5:66.48311
# [400]	validation_0-tweedie-nloglik@1.5:25.52481	validation_1-tweedie-nloglik@1.5:59.44933
# [500]	validation_0-tweedie-nloglik@1.5:25.40656	validation_1-tweedie-nloglik@1.5:57.72130
# [600]	validation_0-tweedie-nloglik@1.5:25.39036	validation_1-tweedie-nloglik@1.5:57.30518
# [700]	validation_0-tweedie-nloglik@1.5:25.38810	validation_1-tweedie-nloglik@1.5:57.17633
# [800]	validation_0-tweedie-nloglik@1.5:25.38775	validation_1-tweedie-nloglik@1.5:57.13032
# [900]	validation_0-tweedie-nloglik@1.5:25.38767	validation_1-tweedie-nloglik@1.5:57.11286
# [1000]	validation_0-tweedie-nloglik@1.5:25.38764	validation_1-tweedie-nloglik@1.5:57.10855
# [1100]	validation_0-tweedie-nloglik@1.5:25.38761	validation_1-tweedie-nloglik@1.5:57.10701
# [1200]	validation_0-tweedie-nloglik@1.5:25.38759	validation_1-tweedie-nloglik@1.5:57.10645
# [1300]	validation_0-tweedie-nloglik@1.5:25.38758	validation_1-tweedie-nloglik@1.5:57.10626
# [1400]	validation_0-tweedie-nloglik@1.5:25.38756	validation_1-tweedie-nloglik@1.5:57.10603
# [1500]	validation_0-tweedie-nloglik@1.5:25.38755	validation_1-tweedie-nloglik@1.5:57.10609
# [1535]	validation_0-tweedie-nloglik@1.5:25.38754	validation_1-tweedie-nloglik@1.5:57.10596

# %%
scores
# Out:
# [15.108224164428881,
#  17.1029217373159,
#  14.501139992307396,
#  3.136722442640417,
#  48.509716510089966]

# %%
# df.loc[(df.index >= '2019-01-01') & (df.index <= '2019-01-08')]['Close'].plot()

# %%
# # train_df['Date'] = pd.to_datetime(train_df.index)
# # test_df['Date'] = pd.to_datetime(test_df.index)

# features = ['year', 'month', 'day', 'dayofweek', 'Open', 'High', 'Low', 'Volume']
# target = 'Close'
# X_train = create_features(train_df)[features] 
# y_train = train_df[target]
# X_test = create_features(test_df)[features]
# y_test = test_df[target]

# reg = xgb.XGBRegressor(n_estimators=2000, learning_rate=0.01)
# reg.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], early_stopping_rounds=50, verbose=100)

# %%
# fi = pd.DataFrame(data=reg.feature_importances_, index=reg.feature_names_in_, columns=['importance'])
# fi.plot(kind='barh', figsize=(10, 10))

# %%
# test_df['Prediction'] = reg.predict(X_test)
# df = df.merge(test_df[['Prediction']], how='left', left_index=True, right_index=True)

# %%
# ax = df[['Close']].plot(figsize=(15, 5))
# df[['Prediction']].plot(ax=ax, style='.')
# ax.legend(["Actual", "Predicted"])
# plt.show()

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-02   20.406668   21.008667   19.920000   20.674667   20.674667
# 2019-01-03   20.466667   20.626667   19.825333   20.024000   20.024000
# 2019-01-04   20.400000   21.200001   20.181999   21.179333   21.179333
# 2019-01-07   21.448000   22.449333   21.183332   22.330667   22.330667
# 2019-01-08   22.797333   22.934000   21.801332   22.356667   22.356667
# ...                ...         ...         ...         ...         ...
# 2020-12-23  210.733337  217.166672  207.523331  215.326660  215.326660
# 2020-12-24  214.330002  222.029999  213.666672  220.589996  220.589996
# 2020-12-28  224.836670  227.133331  220.266663  221.229996  221.229996
# 2020-12-29  220.333328  223.300003  218.333328  221.996674  221.996674
# 2020-12-30  224.000000  232.199997  222.786667  231.593338  231.593338
#
#                Volume
# Date
# 2019-01-02  174879000
# 2019-01-03  104478000
# 2019-01-04  110911500
# 2019-01-07  113268000
# 2019-01-08  105127500
# ...               ...
# 2020-12-23   99519000
# 2020-12-24   68596800
# 2020-12-28   96835800
# 2020-12-29   68732400
# 2020-12-30  128538000
#
# [504 rows x 6 columns]
